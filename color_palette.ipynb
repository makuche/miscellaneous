# %%
# Firefox color palette

import matplotlib.pyplot as plt

colors = ['#201e3b', '#fd703a','#924feb', '#f72e92', '#999aa6', '#ffa237',
          '#8fcfa3', '#f887bd', '#ffc48b']

fig = plt.figure(figsize=(8,1))
plt.box(False)
plt.xticks([])
plt.yticks([])
plt.scatter(np.arange(len(colors)), np.zeros(len(colors)), c=colors, s=1500)
plt.show()
